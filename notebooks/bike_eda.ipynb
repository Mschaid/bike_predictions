# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import seaborn.objects as so
from src import DataProcessing as dp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [49], line 6
#       4 import seaborn as sns
#       5 import seaborn.objects as so
# ----> 6 from src import DataProcessing as dp
#
# ImportError: cannot import name 'DataProcessing' from 'src' (/Users/michaelschaid/GitHub/house_prediction/src/__init__.py)

# %%
df = pd.read_csv(f'/Users/michaelschaid/GitHub/bike_predictions/data/bike_rental_hour.csv')

# %%
bikes.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1
#
#   time_label
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
(
    so.Plot(bikes, x = 'cnt')
    .add(so.Bars(color = 'lightblue', alpha = 0.5, edgecolor = 'k', edgewidth = 0.3), so.Hist(bins = 10))
)

# %%
corr_cnt = pd.DataFrame(bikes.corr()['cnt']).drop(index = 'cnt')
corr_cnt
# Out:
# /var/folders/qr/bdn0nwlj21vbcms1jk872y140000gn/T/ipykernel_62097/1931812115.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_cnt = pd.DataFrame(bikes.corr()['cnt']).drop(index = 'cnt')
#                  cnt
# instant     0.278379
# season      0.178056
# yr          0.250495
# mnth        0.120638
# hr          0.394071
# holiday    -0.030927
# weekday     0.026900
# workingday  0.030284
# weathersit -0.142426
# temp        0.404772
# atemp       0.400929
# hum        -0.322911
# windspeed   0.093234
# casual      0.694564
# registered  0.972151

# %%
(
    so.Plot(corr_cnt, y = corr_cnt.index,x = 'cnt', color = 'cnt')
    .add(so.Bars(alpha = 0.5, edgecolor = 'k', edgewidth = 0.3))
    .label(x="Corr Coef w Cnt", y = '' ,color="")
)
